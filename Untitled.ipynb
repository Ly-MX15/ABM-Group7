# %%
from src.SensitivityAnalysis import *

ranges = {
    "vision_mean": [1, 6],
    "metabolism_mean": [1, 6],
    "max_age_mean": [70, 100],
    "repopulate_factor": [5, 15],
    "cell_regeneration": [1, 5],
}

problem = {
    "num_vars": len(ranges),
    "names": list(ranges.keys()),
    "bounds": list(ranges.values())
}

## Only change split if all files within this split have been run
split = 1

## Set the file_num based on your name
# amish = 1
# priyank = 2
# menghan = 3
# yuan = 4
# ilia = 5
file_num = 2

# Run model
file = f"SA/split_{split}/samples_{file_num}.csv"
run_model(file, replicates=10, max_steps=200)
# Out:
#  23%|██████████████▏                                               | 70/307 [07:20<46:52, 11.87s/it]Process SpawnPoolWorker-791:
# Process SpawnPoolWorker-782:
# Process SpawnPoolWorker-784:
# Process SpawnPoolWorker-788:
# Process SpawnPoolWorker-789:
# Process SpawnPoolWorker-790:
# Process SpawnPoolWorker-787:
# Process SpawnPoolWorker-785:
# Process SpawnPoolWorker-783:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process SpawnPoolWorker-792:
# Process SpawnPoolWorker-786:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.11/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/opt/anaconda3/lib/python3.11/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/opt/anaconda3/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.11/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/opt/anaconda3/lib/python3.11/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/opt/anaconda3/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.11/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/opt/anaconda3/lib/python3.11/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/opt/anaconda3/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/opt/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.11/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/opt/anaconda3/lib/python3.11/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/mesa/__init__.py", line 9, in <module>
#     import mesa.space as space
#   File "/opt/anaconda3/lib/python3.11/site-packages/mesa/space.py", line 32, in <module>
#     import networkx as nx
#   File "/opt/anaconda3/lib/python3.11/site-packages/networkx/__init__.py", line 42, in <module>
#     from networkx import algorithms
#   File "/opt/anaconda3/lib/python3.11/site-packages/networkx/algorithms/__init__.py", line 75, in <module>
#     from networkx.algorithms import isomorphism
#   File "<frozen importlib._bootstrap>", line 1173, in _find_and_load
# KeyboardInterrupt
#   File "/opt/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.11/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/opt/anaconda3/lib/python3.11/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/opt/anaconda3/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/opt/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.11/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/opt/anaconda3/lib/python3.11/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/opt/anaconda3/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/opt/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.11/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/opt/anaconda3/lib/python3.11/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/opt/anaconda3/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/opt/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.11/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/opt/anaconda3/lib/python3.11/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/opt/anaconda3/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/opt/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.11/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/opt/anaconda3/lib/python3.11/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/opt/anaconda3/lib/python3.11/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/opt/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.11/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/opt/anaconda3/lib/python3.11/multiprocessing/queues.py", line 365, in get
#     res = self._reader.recv_bytes()
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/multiprocessing/connection.py", line 430, in _recv_bytes
#     buf = self._recv(4)
#           ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/multiprocessing/connection.py", line 395, in _recv
#     chunk = read(handle, remaining)
#             ^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.11/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/opt/anaconda3/lib/python3.11/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/mesa/__init__.py", line 9, in <module>
#     import mesa.space as space
#   File "/opt/anaconda3/lib/python3.11/site-packages/mesa/space.py", line 32, in <module>
#     import networkx as nx
#   File "/opt/anaconda3/lib/python3.11/site-packages/networkx/__init__.py", line 42, in <module>
#     from networkx import algorithms
#   File "/opt/anaconda3/lib/python3.11/site-packages/networkx/algorithms/__init__.py", line 75, in <module>
#     from networkx.algorithms import isomorphism
#   File "/opt/anaconda3/lib/python3.11/site-packages/networkx/algorithms/isomorphism/__init__.py", line 7, in <module>
#     from networkx.algorithms.isomorphism.vf2pp import *
# KeyboardInterrupt
#  23%|██████████████▏                                               | 70/307 [07:21<24:53,  6.30s/it]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.11/multiprocessing/pool.py:856, in IMapIterator.next(self, timeout)
#     855 try:
# --> 856     item = self._items.popleft()
#     857 except IndexError:
#
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 30
#      28 # Run model
#      29 file = f"SA/split_{split}/samples_{file_num}.csv"
# ---> 30 run_model(file, replicates=2, max_steps=40)
#
# File ~/Desktop/ABM-Group7/src/SensitivityAnalysis.py:58, in run_model(file, replicates, max_steps)
#      56 for row in samples.iterrows():
#      57     params = row[1].to_dict()
# ---> 58     batches = batch_run(SugarScape, params, number_processes=None,
#      59                         iterations=replicates, max_steps=max_steps, display_progress=False)
#      61     for i in range(replicates):
#      62         params["Gini"] = batches[i]["Gini"]
#
# File /opt/anaconda3/lib/python3.11/site-packages/mesa/batchrunner.py:71, in batch_run(model_cls, parameters, number_processes, iterations, data_collection_period, max_steps, display_progress)
#      69 else:
#      70     with Pool(number_processes) as p:
# ---> 71         for data in p.imap_unordered(process_func, runs_list):
#      72             results.extend(data)
#      73             pbar.update()
#
# File /opt/anaconda3/lib/python3.11/multiprocessing/pool.py:861, in IMapIterator.next(self, timeout)
#     859     self._pool = None
#     860     raise StopIteration from None
# --> 861 self._cond.wait(timeout)
#     862 try:
#     863     item = self._items.popleft()
#
# File /opt/anaconda3/lib/python3.11/threading.py:327, in Condition.wait(self, timeout)
#     325 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     326     if timeout is None:
# --> 327         waiter.acquire()
#     328         gotit = True
#     329     else:
#
# KeyboardInterrupt:
