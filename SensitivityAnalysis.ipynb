# %% [markdown]
# # Run Sensitivity Analysis
#
#  Set file_num based on your name. Then run the model with the specified file. The model will run for 10 replicates and 200 steps. The results will be saved in the `SA/split_{split}/samples_{file_num}.csv` file.
# - amish = 1
# - priyank = 2
# - menghan = 3
# - yuan = 4
# - ilia = 5

# %%
from src.Experiments.SensitivityAnalysis import run_model
## Only change split if all files within this split have been run
split = 1

## Set the file_num based on your name
file_num = 4

# Run model
file = f"SensitivityAnalysis/split_{split}/samples_{file_num}.csv"
run_model(file, replicates=10, max_steps=200)
# Out:
#   0%|                                                                       | 0/307 [00:00<?, ?it/s]Process ForkPoolWorker-3:
# Process ForkPoolWorker-8:
# Process ForkPoolWorker-2:
# Process ForkPoolWorker-5:
# Process ForkPoolWorker-4:
# Process ForkPoolWorker-1:
# Process ForkPoolWorker-6:
# Process ForkPoolWorker-7:
#   0%|                                                                       | 0/307 [00:03<?, ?it/s]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File /usr/lib/python3.11/multiprocessing/pool.py:856, in IMapIterator.next(self, timeout)
#     855 try:
# --> 856     item = self._items.popleft()
#     857 except IndexError:
#
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 10
#       8 # Run model
# ...

# %% [markdown]
# # Analyze Sensitivity Analysis

# %%
from src.Experiments.SensitivityAnalysis import load_data, analyse, plot_indices

# Load the results
results = load_data(1)

# Create problem used in SALib
ranges = {
    "vision_mean": [1, 6],
    "metabolism_mean": [1, 6],
    "max_age_mean": [70, 100],
    "repopulate_factor": [5, 15],
    "cell_regeneration": [1, 5],
}

problem = {
    "num_vars": len(ranges),
    "names": list(ranges.keys()),
    "bounds": list(ranges.values())
}

# Perform the analysis
indices = analyse(problem, results)

# Plot the results
fig, ax = plot_indices(indices[0], indices[1], problem)

# Save the plot
fig.savefig("SensitivityAnalysis/indices.png", dpi=300, bbox_inches="tight")
# Out:
# /home/amish/PycharmProjects/School/Block6/ABM-Group7/venv/lib/python3.11/site-packages/SALib/util/__init__.py:274: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   names = list(pd.unique(groups))
